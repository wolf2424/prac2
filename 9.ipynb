# %%
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# Load the Iris dataset
iris = datasets.load_iris()
X = iris.data

# Step 1: Generate the linkage matrix and plot dendrogram
linkage_matrix = linkage(X, method='ward')  # "ward" linkage minimizes variance within clusters

plt.figure(figsize=(10, 6))
dendrogram(linkage_matrix)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel("Sample index")
plt.ylabel("Distance")
plt.show()

# Step 2: Fit the Agglomerative Clustering model
num_clusters = 3  # Define the number of clusters
agg_clustering = AgglomerativeClustering(n_clusters=num_clusters, linkage='ward')
cluster_labels = agg_clustering.fit_predict(X)

# Display results
print("Cluster assignments:")
for i, label in enumerate(cluster_labels):
    print(f"Data point {i} is in cluster {label}")
# Out:
# Cluster assignments:
# Data point 0 is in cluster 1
# Data point 1 is in cluster 1
# Data point 2 is in cluster 1
# Data point 3 is in cluster 1
# Data point 4 is in cluster 1
# Data point 5 is in cluster 1
# Data point 6 is in cluster 1
# Data point 7 is in cluster 1
# Data point 8 is in cluster 1
# Data point 9 is in cluster 1
# Data point 10 is in cluster 1
# Data point 11 is in cluster 1
# Data point 12 is in cluster 1
# Data point 13 is in cluster 1
# Data point 14 is in cluster 1
# Data point 15 is in cluster 1
# Data point 16 is in cluster 1
# Data point 17 is in cluster 1
# Data point 18 is in cluster 1
# Data point 19 is in cluster 1
# Data point 20 is in cluster 1
# Data point 21 is in cluster 1
# Data point 22 is in cluster 1
# Data point 23 is in cluster 1
# Data point 24 is in cluster 1
# Data point 25 is in cluster 1
# Data point 26 is in cluster 1
# Data point 27 is in cluster 1
# Data point 28 is in cluster 1
# Data point 29 is in cluster 1
# Data point 30 is in cluster 1
# Data point 31 is in cluster 1
# Data point 32 is in cluster 1
# Data point 33 is in cluster 1
# Data point 34 is in cluster 1
# Data point 35 is in cluster 1
# Data point 36 is in cluster 1
# Data point 37 is in cluster 1
# Data point 38 is in cluster 1
# Data point 39 is in cluster 1
# Data point 40 is in cluster 1
# Data point 41 is in cluster 1
# Data point 42 is in cluster 1
# Data point 43 is in cluster 1
# Data point 44 is in cluster 1
# Data point 45 is in cluster 1
# Data point 46 is in cluster 1
# Data point 47 is in cluster 1
# Data point 48 is in cluster 1
# Data point 49 is in cluster 1
# Data point 50 is in cluster 0
# Data point 51 is in cluster 0
# Data point 52 is in cluster 0
# Data point 53 is in cluster 0
# Data point 54 is in cluster 0
# Data point 55 is in cluster 0
# Data point 56 is in cluster 0
# Data point 57 is in cluster 0
# Data point 58 is in cluster 0
# Data point 59 is in cluster 0
# Data point 60 is in cluster 0
# Data point 61 is in cluster 0
# Data point 62 is in cluster 0
# Data point 63 is in cluster 0
# Data point 64 is in cluster 0
# Data point 65 is in cluster 0
# Data point 66 is in cluster 0
# Data point 67 is in cluster 0
# Data point 68 is in cluster 0
# Data point 69 is in cluster 0
# Data point 70 is in cluster 0
# Data point 71 is in cluster 0
# Data point 72 is in cluster 0
# Data point 73 is in cluster 0
# Data point 74 is in cluster 0
# Data point 75 is in cluster 0
# Data point 76 is in cluster 0
# Data point 77 is in cluster 2
# Data point 78 is in cluster 0
# Data point 79 is in cluster 0
# Data point 80 is in cluster 0
# Data point 81 is in cluster 0
# Data point 82 is in cluster 0
# Data point 83 is in cluster 0
# Data point 84 is in cluster 0
# Data point 85 is in cluster 0
# Data point 86 is in cluster 0
# Data point 87 is in cluster 0
# Data point 88 is in cluster 0
# Data point 89 is in cluster 0
# Data point 90 is in cluster 0
# Data point 91 is in cluster 0
# Data point 92 is in cluster 0
# Data point 93 is in cluster 0
# Data point 94 is in cluster 0
# Data point 95 is in cluster 0
# Data point 96 is in cluster 0
# Data point 97 is in cluster 0
# Data point 98 is in cluster 0
# Data point 99 is in cluster 0
# Data point 100 is in cluster 2
# Data point 101 is in cluster 0
# Data point 102 is in cluster 2
# Data point 103 is in cluster 2
# Data point 104 is in cluster 2
# Data point 105 is in cluster 2
# Data point 106 is in cluster 0
# Data point 107 is in cluster 2
# Data point 108 is in cluster 2
# Data point 109 is in cluster 2
# Data point 110 is in cluster 2
# Data point 111 is in cluster 2
# Data point 112 is in cluster 2
# Data point 113 is in cluster 0
# Data point 114 is in cluster 0
# Data point 115 is in cluster 2
# Data point 116 is in cluster 2
# Data point 117 is in cluster 2
# Data point 118 is in cluster 2
# Data point 119 is in cluster 0
# Data point 120 is in cluster 2
# Data point 121 is in cluster 0
# Data point 122 is in cluster 2
# Data point 123 is in cluster 0
# Data point 124 is in cluster 2
# Data point 125 is in cluster 2
# Data point 126 is in cluster 0
# Data point 127 is in cluster 0
# Data point 128 is in cluster 2
# Data point 129 is in cluster 2
# Data point 130 is in cluster 2
# Data point 131 is in cluster 2
# Data point 132 is in cluster 2
# Data point 133 is in cluster 0
# Data point 134 is in cluster 0
# Data point 135 is in cluster 2
# Data point 136 is in cluster 2
# Data point 137 is in cluster 2
# Data point 138 is in cluster 0
# Data point 139 is in cluster 2
# Data point 140 is in cluster 2
# Data point 141 is in cluster 2
# Data point 142 is in cluster 0
# Data point 143 is in cluster 2
# Data point 144 is in cluster 2
# Data point 145 is in cluster 2
# Data point 146 is in cluster 0
# Data point 147 is in cluster 2
# Data point 148 is in cluster 2
# Data point 149 is in cluster 0
